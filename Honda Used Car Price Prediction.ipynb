# %% [markdown]
# # <font color='magenta'> <div align="center"> **Prediksi Harga Mobil Honda Bekas dengan Linear Regression** </div>

# %% [markdown]
# <font color='violet'>**Anggota kelompok:**
# ```
# - Daffa Kaisha P.C.     - 00000055770
# - Justine Donovan       - 00000063202
# - Marsella Patricia     - 00000063226
# - Reina Ratu Balqis     - 00000065099
# ```

# %% [markdown]
# ![hondada.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
#
# ### Import Library

# %%
# Basic python
import pandas as pd
import numpy as np

# Statistics
from scipy import stats

# Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Evaluation
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score

# Ignore warning
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# <hr>
#
# ### Baca Data

# %% [markdown]
# Deskripsi dataset: <br>
# Cars.com sekarang menjadi situs rahasia otomotif terbesar kedua dengan banyak koleksi kendaraan untuk dijual. Namun, situs webnya dapat diperpanjang, dan dalam upaya mengumpulkan banyak kendaraan Honda untuk membantu saya memilih antara mobil ekonomis, saya membuat pengikis web untuk mengumpulkan hingga 5.000 kendaraan Honda.
#
# Sumber: https://www.kaggle.com/datasets/omartorres25/honda-data

# %%
cars = pd.read_csv("honda_sell_data.csv")
print("The shape of the dataset: {} \n".format(cars.shape))
cars.head()
# Out:
# The shape of the dataset: (4999, 25)
#    Year   Make                      Model Condition    Price  Consumer_Rating  \
# 0  2023  Honda              Ridgeline RTL       New  $46,370              4.8
# 1  2023  Honda          CR-V Hybrid Sport       New  $34,150              1.7
# 2  2023  Honda          CR-V Hybrid Sport       New  $34,245              4.7
# 3  2022  Honda           Pilot TrailSport       New  $46,500              5.0
# 4  2023  Honda  CR-V Hybrid Sport Touring       New  $40,395              4.4
#
#    Consumer_Review_#           Exterior_Color Interior_Color  \
# 0                  9     Platinum White Pearl          Beige
# 1                 24     Platinum White Pearl          Black
# 2               2869  Meteorite Gray Metallic          Black
# 3                 12         Sonic Gray Pearl          Black
# 4                 12      Crystal Black Pearl          Black
#
#           Drivetrain  ...   Stock_# Mileage Comfort_Rating  \
# 0    All-wheel Drive  ...  00830164      10            5.0
# 1                FWD  ...   6402953       –            5.0
# 2  Front-wheel Drive  ...  PH704805       1            5.0
# 3    All-wheel Drive  ...  5700429B       5            5.0
# 4    All-wheel Drive  ...   5705954       5            5.0
#
#   Interior_Design_Rating Performance_Rating Value_For_Money_Rating  \
# 0                    4.8                4.8                    4.2
# 1                    3.0                4.0                    4.0
# 2                    3.0                4.0                    4.0
# 3                    5.0                5.0                    5.0
# 4                    3.0                4.0                    4.0
#
#   Exterior_Styling_Rating  Reliability_Rating  State  Seller_Type
# 0                     5.0                 5.0     CA       Dealer
# 1                     5.0                 5.0     CA       Dealer
# 2                     5.0                 5.0     CA       Dealer
# 3                     5.0                 5.0     CA       Dealer
# 4                     5.0                 5.0     CA       Dealer
#
# [5 rows x 25 columns]

# %% [markdown]
# Penelitian ini bertujuan untuk memprediksi harga mobil bekas, maka data yang digunakan adalah data mobil bekas.

# %%
# Memilih kondisi mobil bekas
used_cars = cars[cars['Condition'] == 'Used']
used_cars.head()
# Out:
#      Year   Make               Model Condition    Price  Consumer_Rating  \
# 487  2017  Honda           Accord LX      Used  $12,499              4.5
# 514  2016  Honda           Accord EX      Used  $22,998              4.7
# 602  2012  Honda            Civic LX      Used  $14,988              4.5
# 604  2021  Honda         Accord EX-L      Used  $30,998              4.8
# 606  2020  Honda  Accord Hybrid EX-L      Used  $31,598              4.3
#
#      Consumer_Review_#        Exterior_Color Interior_Color  \
# 487                188                 White            Tan
# 514                  0                  Blue           Gray
# 602                  0                     –              –
# 604                  2                   Red           Gray
# 606                623  Platinum White Pearl              –
#
#             Drivetrain  ...   Stock_# Mileage Comfort_Rating  \
# 487  Front-wheel Drive  ...    214342   86667            4.8
# 514  Front-wheel Drive  ...  23826253   53233            4.8
# 602  Front-wheel Drive  ...   CAR9912   45958            4.3
# 604  Front-wheel Drive  ...  23664305   19130            4.9
# 606                FWD  ...  LA016988   17498            4.7
#
#     Interior_Design_Rating Performance_Rating Value_For_Money_Rating  \
# 487                    4.8                4.8                    4.8
# 514                    4.7                4.7                    4.7
# 602                    4.3                4.4                    4.6
# 604                    4.8                4.8                    4.8
# 606                    4.8                4.5                    4.6
#
#     Exterior_Styling_Rating  Reliability_Rating  State  Seller_Type
# 487                     4.8                 4.9     FL       Dealer
# 514                     4.8                 4.8     TX       Dealer
# 602                     4.5                 4.8     CA       Dealer
# 604                     4.9                 4.8     CA       Dealer
# 606                     4.7                 4.8     NV       Dealer
#
# [5 rows x 25 columns]

# %% [markdown]
# <hr>
#
# ### Data Understanding
# Exploratory Data Analysis (EDA)

# %%
# LIhat informasi dari dataset
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2022 entries, 487 to 4997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     2022 non-null   int64
#  1   Make                     2022 non-null   object
#  2   Model                    2022 non-null   object
#  3   Condition                2022 non-null   object
#  4   Price                    2022 non-null   object
#  5   Consumer_Rating          2022 non-null   float64
#  6   Consumer_Review_#        2022 non-null   int64
#  7   Exterior_Color           2018 non-null   object
#  8   Interior_Color           2018 non-null   object
#  9   Drivetrain               2018 non-null   object
#  10  MPG                      1961 non-null   object
#  11  Fuel_Type                2018 non-null   object
#  12  Transmission             2018 non-null   object
#  13  Engine                   2018 non-null   object
#  14  VIN                      2018 non-null   object
#  15  Stock_#                  2018 non-null   object
#  16  Mileage                  2018 non-null   object
#  17  Comfort_Rating           1996 non-null   float64
#  18  Interior_Design_Rating   1996 non-null   float64
#  19  Performance_Rating       1996 non-null   float64
#  20  Value_For_Money_Rating   1996 non-null   float64
#  21  Exterior_Styling_Rating  1996 non-null   float64
#  22  Reliability_Rating       1996 non-null   float64
#  23  State                    1956 non-null   object
#  24  Seller_Type              1956 non-null   object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 410.7+ KB

# %% [markdown]
# Dataset terdiri atas 25 kolom dan 2022 baris.

# %%
# Check missing values
used_cars.isnull().sum()
# Out:
# Year                        0
# Make                        0
# Model                       0
# Condition                   0
# Price                       0
# Consumer_Rating             0
# Consumer_Review_#           0
# Exterior_Color              4
# Interior_Color              4
# Drivetrain                  4
# MPG                        61
# Fuel_Type                   4
# Transmission                4
# Engine                      4
# VIN                         4
# Stock_#                     4
# Mileage                     4
# Comfort_Rating             26
# Interior_Design_Rating     26
# Performance_Rating         26
# Value_For_Money_Rating     26
# Exterior_Styling_Rating    26
# Reliability_Rating         26
# State                      66
# Seller_Type                66
# dtype: int64

# %% [markdown]
# Dataset terdapat missing values, missing values akan di handle dengan cara di hilangkan.
#
# ---

# %%
# Before removing the missing values, we will check what values are contained on each columns on the dataset
# See all uninque values on the column
columns = ['Year', 'Make', 'Model', 'Condition', 'Price', 'Consumer_Rating',
       'Consumer_Review_#', 'Exterior_Color', 'Interior_Color', 'Drivetrain',
       'MPG', 'Fuel_Type', 'Transmission', 'Engine', 'VIN', 'Stock_#',
       'Mileage', 'Comfort_Rating', 'Interior_Design_Rating',
       'Performance_Rating', 'Value_For_Money_Rating',
       'Exterior_Styling_Rating', 'Reliability_Rating', 'State',
       'Seller_Type']
for i in columns:
  print(f"Unique values in column {i}: {used_cars[i].unique()}\n")
  print()
# Out:
# Unique values in column Year: [2017 2016 2012 2021 2020 2014 2023 2019 2018 2022 2011 2000 2009 2004
#  2015 2007 1997 2013 2010 2008 2005 1981 2006 2002 1989 1987 2003 1991
#  1992 2001 1998 1999 1993]
#
#
# Unique values in column Make: ['Honda']
#
#
# Unique values in column Model: ['Accord LX' 'Accord EX' 'Civic LX' 'Accord EX-L' 'Accord Hybrid EX-L'
#  'CR-V EX' 'Accord LX 1.5T' 'Accord Sport 1.5T' 'CR-V EX-L'
#  'Passport Sport' 'Civic Type R Touring' 'Civic EX' 'Insight Touring'
#  'Civic Si Base' 'Pilot EX-L w/ Navigation' 'Civic Sport' 'Passport EX-L'
#  'HR-V Touring' 'Pilot Special Edition' 'HR-V Sport' 'CR-V Hybrid EX-L'
#  'Pilot Touring 7-Passenger' 'S2000 Base' 'Pilot Elite' 'Pilot Touring'
#  'Ridgeline RTL-E' 'Accord Sport' 'Ridgeline RTL-T' 'Accord Sport 2.0T'
#  'HR-V EX' 'Clarity Plug-In Hybrid Base' 'Pilot Black Edition'
#  'Insight EX' 'Element LX' 'Odyssey Elite' 'Pilot EX-L' 'HR-V EX-L'
#  'Odyssey Touring' 'S2000' 'Odyssey SE' 'Ridgeline Sport' 'HR-V LX'
#  'Odyssey EX-L' 'Civic Sport Touring' 'Passport Elite'
#  'Clarity Plug-In Hybrid Touring' 'CR-V Hybrid Touring' 'CR-V Touring'
#  'Crosstour EX-L' 'CR-V Hybrid Sport' 'Civic LX-P' 'Odyssey'
#  'Ridgeline RTL' 'Accord SE' 'Ridgeline Black Edition' 'CR-V Hybrid EX'
#  'Civic EX-L' 'Odyssey LX' 'Accord Hybrid Touring'
#  'Pilot Touring 8-Passenger' 'Civic EX-T' 'CR-V SE' 'CR-Z EX'
#  'Passport TrailSport' 'CR-Z Base (M6)' 'Accord Touring 2.0T' 'CR-V LX'
#  'Odyssey EX' 'Passport Touring' 'CR-Z Base' 'Pilot LX' 'Prelude'
#  'CR-Z LX' 'Odyssey Sport' 'Element EX' 'Civic Si' 'Pilot EX' 'Fit EX'
#  'HR-V EX-L w/Navigation' 'Element EX-P' 'Civic LX-S' 'Fit EX-L'
#  'S2000 Base (M6)' 'Accord Crosstour' 'Accord Touring'
#  'Accord Crosstour EX-L' 'Accord Hybrid Sport' 'Odyssey Touring Elite'
#  'Insight LX' 'Fit' 'Accord Hybrid Base' 'Prelude Si'
#  'Accord Plug-In Hybrid Base' 'Ridgeline RT' 'Accord VP' 'Crosstour EX'
#  'Accord EX-L 1.5T' 'Accord EX 1.5T' 'Civic Hybrid' 'Odyssey EX-L/RES'
#  'Accord LX-P' 'Fit Sport' 'Ridgeline RTX' 'CR-Z EX-L' 'Accord EX-L 2.0T'
#  'Prelude Si 4WS' 'Civic Type R Limited Edition' 'Pilot TrailSport'
#  'Civic Si Base w/High Performance Summer Tires (M6)' 'Ridgeline SE'
#  'Pilot Sport' 'Civic Touring' 'Civic Si Si' 'CR-V Special Edition'
#  'Accord Hybrid EX' 'Civic Hybrid Base' 'Odyssey EX-L w/Navigation/RES'
#  'Accord Sport SE' 'Fit LX' 'Ridgeline Black' 'Fit Base (A5)'
#  'Accord Sport SE 1.5T' 'Prelude Type SH' 'Civic Si Base (M6)' 'Pilot VP'
#  'Fit Sport w/ Navigation' 'Pilot EX-L w/Navigation/RES'
#  'Civic EX-L w/Navi' 'Fit Base' 'Civic Si Base w/Summer Tires (M6)'
#  'Civic GX' 'Insight' 'Civic Hybrid Base w/Leather (CVT)' 'Pilot SE'
#  'CR-Z 3dr CVT' 'Accord LX-S' 'del Sol Si' 'Ridgeline RTS'
#  'Accord EX-L V-6']
#
#
# Unique values in column Condition: ['Used']
#
#
# Unique values in column Price: ['$12,499' '$22,998' '$14,988' ... '$24,177' '$28,955' '$17,495']
#
#
# Unique values in column Consumer_Rating: [4.5 4.7 4.8 4.3 4.6 4.9 4.4 3.5 4.1 5.  4.2 2.7 3.2 2.4 4.  3.9 3.8 3.3
#  2.6 3.4 3.1 2.2 3.  2.5 3.7 2.1 1.3 3.6 2.8 2.  2.9 1.5]
#
#
# Unique values in column Consumer_Review_#: [  188     0     2   623     7  3504  1421    66  1273   169   442   725
#   1346   150   116  1085    82  1880  1445   424  1374  1551   261    33
#    806   250   459  1144  1304  1330   279   840   412  1524   531    54
#   1842   451   449   107    79    42    85   920    47   110    15   248
#    535   463    32  1992   697     8   172   572  2857     3  2257   880
#     72  1138   560   665   305  1192   314  3004  1919   889  3229   679
#     61    48    20  2871    57   175    29  2791  5590  1385  1600  1532
#   1930  1494  9531     1   171  4154  2231  2352   333   170   599  1202
#    475    31   615   149  1727   202  2014    17  1757    64   822  1278
#    427  2166  2681  7642  9532   648   747   382  4978   154  2386   334
#   1991   592   140   151  9533  1864    22   655   232    10   706    38
#     62    49    59  1922   204  1102     5   162  2341   717    28  1022
#     60  2884   469   336    65   212  2602  1066   453  1147  1257  3452
#    168   115   229   430   139   239    24   210   596   165  5045   164
#    391   284   594  1114  2950   158    76  9557  1628   403   122   372
#      4  1074   345   177  2487  4272  9545  1933  1125  1061   821   470
#    173  4246   456  3812     6  1571  1184    80    73   113  2200   447
#    794  1701   263   955   220  1855   205    16    44  3181   389    90
#   4442   352   500  1075    51   377  1036   621   189   291  1988  1014
#   9544  4876   361   208     9  1416   223  3868   705  1031   323  3113
#     40    67   108   288  5648   879   530   152    35  1296   942    26
#    179   527   841   227  1359  1781   267   954  1030   928 13041  9534
#   1037   890   216   271   161   820  1963   484   637    13    12  1545
#     21  1028   498   257  1351   472   896   249   523   516  2990    11
#   2598   922   123   228   346  7494  1080   743   436   106    19  1116
#    415    75   337   313  4354   105   224  9563  1976   985   425  1838
#     56   325   837  1654   235   144   421   862   614  1027  1737   181
#    206   524   611    50    36   185  1650  1126   153  1495   639  3028
#   2110    84   457   187  1358  1272  7415  3031    86  1500    41   109
#    640  1079   285  1833  1641    14  2637   367    18    81   781   423
#   4871   273   973  1337  5490   374  2538  1120   409   194  1732   127
#    558    53   348  7129  1771  1625   260  1086   145    95    91   219
#    878    89   304   715   562  5162  6558   231   111   734  1874  1789
#   1053    63  1043   492   125  8147  3427   222   537  4044   317   778
#    102    83   429   128  2581  2761   727  1308   103   804   277  1169
#    136    92   343    27  2397  2019   295   365   114  1324   290   564
#   1555   441  2756  1621    55  2361  1688   937  3749   226  4929  1430
#    307   786   801   788  4140   471   796   851   146  1508   602   297
#    650   327  5006  1332   823  1733   551  3087   613   437    88   201
#   1576   100  1362   953  2722  2760  3692   905  1026   363   509  3314
#    844  1045  1259 29258   682  2653   730  2068  4295   147  9537   358
#    118   354   877  3710  5418   321  1828   764  1846   309   784   876
#    155   502  1736  1034  1436   131   413  3935   375   230    45   328
#    832  1357   280  1267  1983  1565  3764   756   996 22425  2619   440
#    914  1155    25  6573   454  1201  4218  1007   266  4630   386  1871
#     71  1444    93  1103   912    30   178  1143  1248   322   556   318
#    925   539   244   252  6228  3538   275  2176  1219  2504   505   299
#   1929   990  2879  6225  4669    23   399  2422  1627   213   485  1485
#   1152   142   478   661   176   434  2499  1480   387   126   191   203
#     78   218   124   101   546  4156  3405   915   549  1714  6788  9535
#   1055   795   931   344  2284 22428    43   932   634   364   636  3531
#    200  1174  3404   774  1893  3139   306  1024  1050   329   704   770
#   3575  4786   969   240  2029   292   350  3063   742  1579   712   906
#   1826  1253   698   300   904   555   998  1258   417  1052   112   134
#    197   349  2296  1969   644  1492  1065  1777  2195  1614  1751  3822
#   1100   141   886   246   619    98   251   934  1905  4793  1009  2579
#   1241  1160    37   907    77  7330   513   340  3996  1944  3454  1696
#   1018  1822  1166   565   435  4591  1464  1230   276    46   695   723
#   1831   647  2034  2634  3179   733   278   825  1371   744   431  1647
#   2376  4912  1498   961  2503  1130  3758   433  3534    74  4324   215
#    119  9467  1063  2869   133   598   948  1596    87   966   330   157
#   2147    52   198  9536  3040   970   310   590  1862  2727  1020   525
#   5604  1168  3600  1504   166   468   583   830   951  3879   274 11948
#   5248    39  2925   610   193  1318  3512  1916  3200  1975   710    69
#    192   163  1486  2286  2694   182  2700  6749   967   214   766  2569
#   1004   677  2136  4072   443  1047   190   455   529  1077  2440    58
#    638   446   160  1516   950  1239   416  1162  5766   186  8363   958
#   6877  5684   394   746    68   137   392    34   368  4570   341  3782
#    709   497   857  1836   241  3891   641   707   396   255  1163   569
#   1747   245  2395  1081  2546  1501  4034   921   294   745  1559  4199
#   1056   298   400   301  1279  1068  1964   858  1276   452  2327  1902
#    609  6892   624   568  3234  1925]
#
#
# Unique values in column Exterior_Color: ['White' 'Blue' '–' 'Red' 'Platinum White Pearl' 'Brown' 'Silver'
#  'San Marino Red' 'White Diamond Pearl' 'Crystal Black Pearl'
#  'Lunar Silver Metallic' 'Modern Steel Metallic' 'Aegean Blue Metallic'
#  'Taffeta White' 'Silver Metallic' 'Steel Sapphire Metallic'
#  'Still Night Pearl' 'Pewter' 'Black' 'NH 877' 'New Formula Red'
#  'Deep Scarlet Pearl' 'Radiant Red Metallic II' 'Pacific Pewter Metallic'
#  'Radiant Red Metallic' 'Boost Blue Pearl' 'Kona Coffee Metallic' 'Pearl'
#  'Graphite Pearl' 'Burgundy' 'Gray' 'Sonic Gray Pearl' 'Green'
#  'Cosmic Blue Metallic' 'Maroon' 'Platinum' 'Champagne Frost Pearl'
#  'Nighthawk Black Pearl' 'Satin Silver Metallic' 'Lunar' 'Milano Red'
#  'Aegean Blue' 'Mar' 'Smoky Topaz Metallic' 'Obsidian Blue Pearl'
#  'Alabaster Silver Metallic' 'White Orchid Pearl' 'UNKNOWN'
#  'Premium White' 'Basque Red Pearl II' 'Misty Green'
#  'Glacier Blue Metallic' 'Midnight Amethyst' 'Polished Metal Metallic'
#  'Silver Moss Metallic' 'Blazing Orange Pearl' 'Deep Violet'
#  'Smokey Mauve Pearl' 'Bali Blue Pearl' 'Charcoal' 'Gold'
#  'Championship White' 'BLACK' 'Black Copper Pearl' 'Beige'
#  'Solar Silver Metallic' 'Rallye Red' nan 'Meteorite Gray Metallic'
#  'BLUE**SUPER CLEAN, LOW MILES AND BACKED BY WARRANT' 'Energy Green Pearl'
#  'Royal Blue Pearl' '01' 'Platinum White' 'Blue Metallic'
#  'Diamond White Pearl' 'Mediterranean Blue Pearl' 'Phoenix Yellow'
#  'Galaxy Gray Metallic' 'Tangerine Metallic' 'Atomic Blue Metallic'
#  'Molten Lava Pearl' 'Gunmetal Metallic' 'Deep Scarlet' 'Crystal Black'
#  'Silverstone Metallic' 'Slate Green Metallic' 'Dark Cherry Pearl'
#  'Purple' 'Lunar Silver' 'Eternal Blue Pearl' 'Desert Mist Metallic'
#  'Suzuka Blue Metallic' 'Pearl White' 'PEWTER' 'Tan' 'Silver Gray'
#  'MAROON' 'Modern Steel Metallic Gray' 'Special' 'Black Forest Pearl'
#  'Storm Silver Metallic' 'Yellow' 'Crimson Pearl' 'White Diamond'
#  'Meteorite' 'COSMIC BLUE' 'OBSIDION BLUE' 'Black Obsidian'
#  'Morning Mist Metallic' 'Berlina Black' 'CRYSTAL BLACK' 'Fiji Blue Pearl'
#  'Basque Red Pearl' 'Orange' 'Mountain Air Metallic' 'Tango Red Pearl'
#  'red' 'Mandarin Gold Metallic' 'Whistler Silver Metallic' 'CELESTITE'
#  'RED' 'Midnight Blue Metallic' 'Hematite Metallic' 'Navy Blue'
#  'Dyno Blue Pearl' 'WHITE' 'Blue Pearl' 'BLUE' 'Bright White'
#  'Premium White Pearl' 'Obsidian Blue' 'Deep Velvet Blue Pearl'
#  'Dark Gray']
#
#
# Unique values in column Interior_Color: ['Tan' 'Gray' '–' 'Black' 'Red / Black' 'Beige' 'Ivory' 'Titanium' 'Mocha'
#  'Black / Red' 'Truffle' 'Black / Gray' 'Gray / Silver' 'Red' 'Graphite'
#  'Biege' 'Cream' 'Parchment' 'Grey' 'Blue' 'Sport' '.' nan 'Stone'
#  'Black/Red' 'Black / Titanium' 'Gray / Blue' 'Select' 'Gray/Blue'
#  'Black / Ivory' 'BLACK' 'Interior' 'Burgundy' 'Gray/Black' 'Silver'
#  'Nighthawk Black Pearl / Grey']
#
#
# Unique values in column Drivetrain: ['Front-wheel Drive' 'FWD' 'All-wheel Drive' 'Rear-wheel Drive' '–'
#  'Four-wheel Drive' 'AWD' nan]
#
#
# Unique values in column MPG: ['27–36' '27–37' '28–39' '30–38' '48–47' '22–30' '29–35' '28–34' '19–24'
#  '22–28' '33–42' '51–45' '26–36' '18–26' '30–37' '31–40' '26–31' '25–36'
#  '19–26' '40–35' '20–26' '18–25' '26–35' '22–32' nan '55–49' '27–32'
#  '19–28' '21–30' '20–27' '20–25' '18–24' '27–31' '19–27' '31–41' '0–0'
#  '27–34' '30–39' '20–29' '16–22' '23–29' '32–42' '44–41' '31–42' '25–31'
#  '31–38' '17–24' '30–41' '24–34' '49–47' '22–31' '47–47' '21–31' '15–20'
#  '21–27' '32–38' '17–25' '26–34' '23–34' '23–31' '29–37' '21–28' '21–24'
#  '26–33' '18–27' '22–26' '27–33' '29–38' '26–32' '28–38' '21–34' '48–48'
#  '21–29' '22–27' '20–30' '28–0' '46–51' '19–29' '28–35' '30–40' '25–33'
#  '44–44' '28–36' '31–36' '36–39' '24–33' '19–25' '15–21' '32–37' '23–27'
#  '8–34.6' '16–23' '50–45' '31–39' '29–36' '30–36' '24–31' '44–47' '21–26'
#  '28–40' '40–43' '23–32' '22–33' '33–40' '19–0' '17–22' '31–31' '17–23'
#  '33–41' '16–20' '20–28' '24–36' '20–27.0' '33–33' '41–44' '40–45' '31–37'
#  '29–33' '23–30']
#
#
# Unique values in column Fuel_Type: ['Gasoline' 'Hybrid' nan '5-Speed A/T' 'A/T' '6-Speed M/T'
#  'CVT Transmission' 'Compressed Natural Gas']
#
#
# Unique values in column Transmission: ['Automatic CVT' '5-Speed Automatic' 'continuously variable automatic'
#  '9-Speed Automatic' '6-Speed Manual' '6-Speed Automatic' 'Automatic'
#  '10-Speed Automatic' 'continuously variable w/sport mode' 'CVT'
#  'Variable' '4-Speed Automatic' 'Manual' 'continuously variable'
#  'continuously variable (cvt)' '10-SPEED A/T' '5-Speed Manual'
#  '6-SPEED A/T' 'continuously variable (m cvt)' '5-SPEED A/T' nan
#  '177.0HP 2.4L 4 Cylinder Engine Gasoline Fuel'
#  'Close-Ratio 6-Speed Manual' '9-SPEED A/T' '5-SPEED M/T'
#  '10 speed automatic' '166.0HP 2.4L 4 Cylinder Engine Gasoline Fuel'
#  '241.0HP 3.5L V6 Cylinder Engine Gasoline Fuel'
#  '240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel' '4-SPEED A/T'
#  '5 Speed Automatic' '141.0HP 1.8L 4 Cylinder Engine Gasoline Fuel'
#  'continuously variable (ll cvt)' '9 speed automatic'
#  'e continuously variable (e cvt)' 'AUTOMATIC'
#  'Continuously Variable Transmission' 'Automatic 5-Speed' 'eCVT'
#  'Automatic, 6-Spd' '6-SPEED M/T' 'electric continuously variable'
#  'CVT TRANSMISSION' 'electronic continuously variable' 'Automatic, 5-Spd'
#  '205.0HP 1.5L 4 Cylinder Engine Gasoline Fuel' '1-Speed CVT w/OD']
#
#
# Unique values in column Engine: ['2.4L I4 16V GDI DOHC' '1.8L I4 16V MPFI SOHC'
#  '1.5L I4 16V GDI DOHC Turbo' '2.0L I4 16V MPFI DOHC Hybrid'
#  '2.4L I4 16V MPFI DOHC' '4 Cylinder Engine' '3.5L V6 24V GDI SOHC'
#  '2.0L I4 16V GDI DOHC Turbo' '1.5L I4 16V MPFI DOHC Hybrid'
#  '2.0L I4 16V MPFI DOHC' '2.0L I4 16V GDI DOHC'
#  'Regular Unleaded V-6 3.5 L/212' '2.2L I4 16V MPFI DOHC'
#  '3.5L V6 24V MPFI SOHC' '1.5L 4 Cyl.' 'Gas/Electric I-4 1.5 L/91'
#  '2.0L I4 16V GDI DOHC Hybrid' '3.0L V6 24V MPFI SOHC'
#  '2.2L I4 16V MPFI SOHC' '1.5L I4 16V MPFI SOHC Hybrid'
#  'V6 Cylinder Engine' 'Gas/Electric I4 1.5L/91'
#  'Gas/Electric I-4 2.0 L/122' '1.8L I4 12V 3 BBL SOHC'
#  '1.5L I4 16V GDI DOHC' 'Engine: 3.5L V6 24-Valve SOHC i-VTEC'
#  '1.5L I4 16V MPFI SOHC' '2.0L I4 16V DOHC' 'Gas V6 3.5L/212'
#  'Intercooled Turbo Regular Unleaded I-4 1.5 L/91'
#  '1.3L I4 8V MPFI SOHC Hybrid' '2.0L I4 12V SOHC' '2.0L 4 Cylinder'
#  '1.7L SOHC 16-valve I4 ULEV-certified engine' nan '1HGCP2F46CA229037'
#  '1.5L I4 8V MPFI SOHC Hybrid'
#  '1.5L SOHC MPFI 8-valve 2-stage i-VTEC I4 hybrid engine w/permane'
#  '1.5L I4 16V SOHC' '5J6YH28387L013460' '5FNRL38768B010482' '2.2 H22A'
#  'Regular Unleaded I-4 2.0 L/122'
#  'Intercooled Turbo Premium Unleaded I-4 1.5 L/91'
#  '1.8L SOHC MPFI 16-valve i-VTEC I4 engine' 'JHMAP114X1T007821'
#  '1.5L Turbo I4 192hp 192ft. lbs.' '3CZRU6H51HM725334'
#  '1.7L I4 16V MPFI SOHC' 'Regular Unleaded I-4 2.4 L/144'
#  '2.4L DOHC MPFI i-VTEC 16-valve I4 engine' '2.3L I4 16V MPFI SOHC'
#  'Gas I4 2.0L/121.9' 'I4 2.4L Natural Aspiration'
#  '2.4L I4 DOHC 16V i-VTEC'
#  'Intercooled Turbo Regular Unleaded I-4 2.0 L/122'
#  '1.8L I4 16V MPFI SOHC CNG' '2.4L I4 DOHC i-VTEC 16V' 'Gas V6 3.5L/'
#  '2HGFC1E53LH708207' '1.6L I4 16V MPFI SOHC'
#  '2.4L DOHC MPFI 16-valve i-VTEC I4 engine']
#
#
# Unique values in column VIN: ['1HGCR2F31HA214342' '1HGCR2F76GA178536' '2HGFB2F55CH574811' ...
#  '3HGGK5H49LM706349' 'SHHFK7G48JU206786' '1HGCP3F83BA030969']
#
#
# Unique values in column Stock_#: ['214342' '23826253' 'CAR9912' ... '36117' 'NA073727A' '22941503']
#
#
# Unique values in column Mileage: ['86667' '53233' '45958' ... '40902' '82906' '88050']
#
#
# Unique values in column Comfort_Rating: [4.8 4.3 4.9 4.7 4.5 5.  4.6 4.1 4.2 nan 4.4 3.8 4.  3.9]
#
#
# Unique values in column Interior_Design_Rating: [4.8 4.7 4.3 4.5 5.  4.9 4.6 4.2 nan 4.4 3.2 3.  4.  4.1]
#
#
# Unique values in column Performance_Rating: [4.8 4.7 4.4 4.5 5.  4.9 4.3 nan 3.6 4.6 4.  4.2 4.1 3.9 3.8 3.7]
#
#
# Unique values in column Value_For_Money_Rating: [4.8 4.7 4.6 4.5 4.  5.  4.3 4.9 4.4 nan 3.6 4.1 4.2 3.9 3.8]
#
#
# Unique values in column Exterior_Styling_Rating: [4.8 4.5 4.9 4.7 4.6 4.  5.  4.3 nan 4.2 4.4 4.1 3.9]
#
#
# Unique values in column Reliability_Rating: [4.9 4.8 4.7 5.  4.4 4.6 nan 4.5 4.2 4.3 4.1 4. ]
#
#
# Unique values in column State: ['FL' 'TX' 'CA' 'NV' 'AZ' 'OR' 'ID' 'WA' 'MT' 'SD' 'OK' 'NE' 'IA' 'KS'
#  'AR' 'ND' 'MO' 'MN' 'LA' 'IL' 'WI' 'IN' 'TN' 'MI' 'AL' 'KY' 'OH' 'NC'
#  'SC' 'VA' 'NY' 'PA' 'MD' 'AK' 'NJ' 'MA' 'ME' nan 'WV' 'UT' 'GA' 'CO' 'VT'
#  'HI' 'MS' 'CT' 'NH' 'WY' 'NM' 'Glens' 'MO-22' 'RI']
#
#
# Unique values in column Seller_Type: ['Dealer' nan 'Individual']

# %%
unique_value_counts = {}
for column in columns:
    unique_values = used_cars[column].unique()
    unique_count = len(unique_values)
    unique_value_counts[column] = unique_count

print("Sum of unique values in each column:")
for column, count in unique_value_counts.items():
    print(f"{column}: {count}")
# Out:
# Sum of unique values in each column:
# Year: 33
# Make: 1
# Model: 139
# Condition: 1
# Price: 1370
# Consumer_Rating: 32
# Consumer_Review_#: 858
# Exterior_Color: 134
# Interior_Color: 36
# Drivetrain: 8
# MPG: 119
# Fuel_Type: 8
# Transmission: 47
# Engine: 62
# VIN: 2019
# Stock_#: 2018
# Mileage: 2002
# Comfort_Rating: 14
# Interior_Design_Rating: 14
# Performance_Rating: 16
# Value_For_Money_Rating: 15
# Exterior_Styling_Rating: 13
# Reliability_Rating: 12
# State: 52
# Seller_Type: 3

# %%
# Replace values "-" to None on column 'Exterior_Color', 'Interior_Color', 'Drivetrain'
col = ['Exterior_Color', 'Interior_Color', 'Drivetrain']
for i in col:
  used_cars[i].replace('–', None, inplace=True)

used_cars.head()
# Out:
#      Year   Make               Model Condition    Price  Consumer_Rating  \
# 487  2017  Honda           Accord LX      Used  $12,499              4.5
# 514  2016  Honda           Accord EX      Used  $22,998              4.7
# 602  2012  Honda            Civic LX      Used  $14,988              4.5
# 604  2021  Honda         Accord EX-L      Used  $30,998              4.8
# 606  2020  Honda  Accord Hybrid EX-L      Used  $31,598              4.3
#
#      Consumer_Review_#        Exterior_Color Interior_Color  \
# 487                188                 White            Tan
# 514                  0                  Blue           Gray
# 602                  0                  None           None
# 604                  2                   Red           Gray
# 606                623  Platinum White Pearl           None
#
#             Drivetrain  ...   Stock_# Mileage Comfort_Rating  \
# 487  Front-wheel Drive  ...    214342   86667            4.8
# 514  Front-wheel Drive  ...  23826253   53233            4.8
# 602  Front-wheel Drive  ...   CAR9912   45958            4.3
# 604  Front-wheel Drive  ...  23664305   19130            4.9
# 606                FWD  ...  LA016988   17498            4.7
#
#     Interior_Design_Rating Performance_Rating Value_For_Money_Rating  \
# 487                    4.8                4.8                    4.8
# 514                    4.7                4.7                    4.7
# 602                    4.3                4.4                    4.6
# 604                    4.8                4.8                    4.8
# 606                    4.8                4.5                    4.6
#
#     Exterior_Styling_Rating  Reliability_Rating  State  Seller_Type
# 487                     4.8                 4.9     FL       Dealer
# 514                     4.8                 4.8     TX       Dealer
# 602                     4.5                 4.8     CA       Dealer
# 604                     4.9                 4.8     CA       Dealer
# 606                     4.7                 4.8     NV       Dealer
#
# [5 rows x 25 columns]

# %%
# Drop baris yang memiliki null values
used_cars = used_cars.dropna(axis=0)
print(used_cars.info())
print()
print(used_cars.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1542 entries, 487 to 4997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     1542 non-null   int64
#  1   Make                     1542 non-null   object
#  2   Model                    1542 non-null   object
#  3   Condition                1542 non-null   object
#  4   Price                    1542 non-null   object
#  5   Consumer_Rating          1542 non-null   float64
#  6   Consumer_Review_#        1542 non-null   int64
#  7   Exterior_Color           1542 non-null   object
#  8   Interior_Color           1542 non-null   object
#  9   Drivetrain               1542 non-null   object
#  10  MPG                      1542 non-null   object
#  11  Fuel_Type                1542 non-null   object
#  12  Transmission             1542 non-null   object
#  13  Engine                   1542 non-null   object
#  14  VIN                      1542 non-null   object
#  15  Stock_#                  1542 non-null   object
#  16  Mileage                  1542 non-null   object
#  17  Comfort_Rating           1542 non-null   float64
#  18  Interior_Design_Rating   1542 non-null   float64
#  19  Performance_Rating       1542 non-null   float64
#  20  Value_For_Money_Rating   1542 non-null   float64
#  21  Exterior_Styling_Rating  1542 non-null   float64
#  22  Reliability_Rating       1542 non-null   float64
#  23  State                    1542 non-null   object
#  24  Seller_Type              1542 non-null   object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 313.2+ KB
# None
#
# Year                       0
# Make                       0
# Model                      0
# Condition                  0
# Price                      0
# Consumer_Rating            0
# Consumer_Review_#          0
# Exterior_Color             0
# Interior_Color             0
# Drivetrain                 0
# MPG                        0
# Fuel_Type                  0
# Transmission               0
# Engine                     0
# VIN                        0
# Stock_#                    0
# Mileage                    0
# Comfort_Rating             0
# Interior_Design_Rating     0
# Performance_Rating         0
# Value_For_Money_Rating     0
# Exterior_Styling_Rating    0
# Reliability_Rating         0
# State                      0
# Seller_Type                0
# dtype: int64

# %% [markdown]
# Setelah missing values dibersihkan, dataset terdiri atas 1542 baris and 25 kolom.

# %% [markdown]
# Kami akan mengganti tipe data kolom Mileage menjadi integer.

# %%
# Convert Price column
# Define a function to convert USD to IDR
def usd(amount_usd):
    usd = int(amount_usd.replace(',', '').strip('$'))
    return usd

# Apply the conversion function
used_cars['Price'] = used_cars['Price'].apply(usd)

# Convert Mileage column to integer
used_cars['Mileage'] = used_cars['Mileage'].astype(int)

used_cars.head()
# Out:
#      Year   Make           Model Condition  Price  Consumer_Rating  \
# 487  2017  Honda       Accord LX      Used  12499              4.5
# 514  2016  Honda       Accord EX      Used  22998              4.7
# 604  2021  Honda     Accord EX-L      Used  30998              4.8
# 607  2014  Honda         CR-V EX      Used  16998              4.5
# 609  2020  Honda  Accord LX 1.5T      Used  23544              4.3
#
#      Consumer_Review_# Exterior_Color Interior_Color         Drivetrain  ...  \
# 487                188          White            Tan  Front-wheel Drive  ...
# 514                  0           Blue           Gray  Front-wheel Drive  ...
# 604                  2            Red           Gray  Front-wheel Drive  ...
# 607                  7          Brown          Black    All-wheel Drive  ...
# 609               3504         Silver          Black  Front-wheel Drive  ...
#
#       Stock_# Mileage Comfort_Rating Interior_Design_Rating  \
# 487    214342   86667            4.8                    4.8
# 514  23826253   53233            4.8                    4.7
# 604  23664305   19130            4.9                    4.8
# 607  23434682  105979            4.5                    4.5
# 609   181965A   32910            4.8                    4.8
#
#     Performance_Rating Value_For_Money_Rating  Exterior_Styling_Rating  \
# 487                4.8                    4.8                      4.8
# 514                4.7                    4.7                      4.8
# 604                4.8                    4.8                      4.9
# 607                4.5                    4.5                      4.6
# 609                4.8                    4.8                      4.9
#
#      Reliability_Rating  State  Seller_Type
# 487                 4.9     FL       Dealer
# 514                 4.8     TX       Dealer
# 604                 4.8     CA       Dealer
# 607                 4.7     NV       Dealer
# 609                 4.9     AZ       Dealer
#
# [5 rows x 25 columns]

# %%
# Check the basic statistics on the dataset
# Numeric data type
used_cars.describe()
# Out:
#               Year         Price  Consumer_Rating  Consumer_Review_#  \
# count  1542.000000   1542.000000      1542.000000        1542.000000
# mean   2017.957847  26355.167315         4.566213         924.003891
# std       4.149874   8924.657089         0.480948        2037.365763
# min    1992.000000   1995.000000         1.300000           0.000000
# 25%    2017.000000  20382.000000         4.400000          35.250000
# 50%    2019.000000  26977.000000         4.700000         263.000000
# 75%    2021.000000  32723.750000         4.900000        1063.000000
# max    2023.000000  69980.000000         5.000000       29258.000000
#
#              Mileage  Comfort_Rating  Interior_Design_Rating  \
# count    1542.000000     1542.000000             1542.000000
# mean    53108.441634        4.716278                4.676200
# std     41339.104657        0.217325                0.227158
# min       566.000000        3.800000                3.200000
# 25%     22163.500000        4.600000                4.600000
# 50%     42107.000000        4.800000                4.700000
# 75%     74217.500000        4.800000                4.800000
# max    259029.000000        5.000000                5.000000
#
#        Performance_Rating  Value_For_Money_Rating  Exterior_Styling_Rating  \
# count         1542.000000             1542.000000              1542.000000
# mean             4.644942                4.608171                 4.718029
# std              0.233634                0.227415                 0.163826
# min              3.600000                3.600000                 4.000000
# 25%              4.500000                4.500000                 4.600000
# 50%              4.700000                4.600000                 4.700000
# 75%              4.800000                4.800000                 4.800000
# max              5.000000                5.000000                 5.000000
#
#        Reliability_Rating
# count         1542.000000
# mean             4.751427
# std              0.181192
# min              4.000000
# 25%              4.700000
# 50%              4.800000
# 75%              4.800000
# max              5.000000

# %%
# Check the basic statistics on the dataset
# Categorical data type
used_cars.describe(exclude=np.number)
# Out:
#          Make         Model Condition       Exterior_Color Interior_Color  \
# count    1542          1542      1542                 1542           1542
# unique      1           125         1                  109             32
# top     Honda  Odyssey EX-L      Used  Crystal Black Pearl          Black
# freq     1542            85      1542                  159            820
#
#                Drivetrain    MPG Fuel_Type   Transmission  \
# count                1542   1542      1542           1542
# unique                  6    109         3             33
# top     Front-wheel Drive  19–28  Gasoline  Automatic CVT
# freq                  970    167      1408            555
#
#                       Engine                VIN Stock_# State Seller_Type
# count                   1542               1542    1542  1542        1542
# unique                    44               1542    1542    50           1
# top     3.5L V6 24V GDI SOHC  1HGCR2F31HA214342  214342    FL      Dealer
# freq                     545                  1       1   116        1542

# %%
# Check outliers using boxplot on Price column
sns.boxplot(y=used_cars['Price'])
plt.title("Check outliers using Boxplot\n")
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see, there are 2 outliers on the Price column. We need to remove it.

# %%
# Remove outliers using z-score
z_scores = stats.zscore(used_cars['Price'])

# Remove outliers from the dataset
used_cars = used_cars[(z_scores <= 3) & (z_scores >= -3)]

# Create the boxplot to check if the outliers are already handled
sns.boxplot(y=used_cars['Price'])
plt.title("Check outliers using Boxplot\n")
plt.tight_layout()
plt.show()

# %% [markdown]
# Outliers already handled

# %%
# Visualize the price distribution
sns.histplot(used_cars['Price'], kde=True)
plt.title("Used Honda Car Price Distribution\n")
plt.tight_layout()
plt.show()

# %%
# Recheck the information of the dataset
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1540 entries, 487 to 4997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     1540 non-null   int64
#  1   Make                     1540 non-null   object
#  2   Model                    1540 non-null   object
#  3   Condition                1540 non-null   object
#  4   Price                    1540 non-null   int64
#  5   Consumer_Rating          1540 non-null   float64
#  6   Consumer_Review_#        1540 non-null   int64
#  7   Exterior_Color           1540 non-null   object
#  8   Interior_Color           1540 non-null   object
#  9   Drivetrain               1540 non-null   object
#  10  MPG                      1540 non-null   object
#  11  Fuel_Type                1540 non-null   object
#  12  Transmission             1540 non-null   object
#  13  Engine                   1540 non-null   object
#  14  VIN                      1540 non-null   object
#  15  Stock_#                  1540 non-null   object
#  16  Mileage                  1540 non-null   int32
#  17  Comfort_Rating           1540 non-null   float64
#  18  Interior_Design_Rating   1540 non-null   float64
#  19  Performance_Rating       1540 non-null   float64
#  20  Value_For_Money_Rating   1540 non-null   float64
#  21  Exterior_Styling_Rating  1540 non-null   float64
#  22  Reliability_Rating       1540 non-null   float64
#  23  State                    1540 non-null   object
#  24  Seller_Type              1540 non-null   object
# dtypes: float64(7), int32(1), int64(3), object(14)
# memory usage: 306.8+ KB

# %% [markdown]
# The data now contain 1540 rows and 25 columns, with no outliers and no null values. <br>
# <hr>

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Choosing the metrics for model building later

# %%
# Make a copy of used_cars dataset
used = used_cars.copy()
used.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1540 entries, 487 to 4997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     1540 non-null   int64
#  1   Make                     1540 non-null   object
#  2   Model                    1540 non-null   object
#  3   Condition                1540 non-null   object
#  4   Price                    1540 non-null   int64
#  5   Consumer_Rating          1540 non-null   float64
#  6   Consumer_Review_#        1540 non-null   int64
#  7   Exterior_Color           1540 non-null   object
#  8   Interior_Color           1540 non-null   object
#  9   Drivetrain               1540 non-null   object
#  10  MPG                      1540 non-null   object
#  11  Fuel_Type                1540 non-null   object
#  12  Transmission             1540 non-null   object
#  13  Engine                   1540 non-null   object
#  14  VIN                      1540 non-null   object
#  15  Stock_#                  1540 non-null   object
#  16  Mileage                  1540 non-null   int32
#  17  Comfort_Rating           1540 non-null   float64
#  18  Interior_Design_Rating   1540 non-null   float64
#  19  Performance_Rating       1540 non-null   float64
#  20  Value_For_Money_Rating   1540 non-null   float64
#  21  Exterior_Styling_Rating  1540 non-null   float64
#  22  Reliability_Rating       1540 non-null   float64
#  23  State                    1540 non-null   object
#  24  Seller_Type              1540 non-null   object
# dtypes: float64(7), int32(1), int64(3), object(14)
# memory usage: 306.8+ KB

# %% [markdown]
# #### Encoding categorical values

# %%
# Initialize LabelEncoder
le = LabelEncoder()

# Select column wiht categorical values
cols = ['Model', 'Make', 'Condition', 'Seller_Type', 'Drivetrain', 'MPG', 'Fuel_Type', 'Transmission', 'Engine', 'State', 'VIN', 'Stock_#', 'Interior_Color', 'Exterior_Color']
for i in cols:
    used[i] = le.fit_transform(used[i]) + 1

# Check the data
used.head()
# Out:
#      Year  Make  Model  Condition  Price  Consumer_Rating  Consumer_Review_#  \
# 487  2017     1     13          1  12499              4.5                188
# 514  2016     1      3          1  22998              4.7                  0
# 604  2021     1      5          1  30998              4.8                  2
# 607  2014     1     26          1  16998              4.5                  7
# 609  2020     1     14          1  23544              4.3               3504
#
#      Exterior_Color  Interior_Color  Drivetrain  ...  Stock_#  Mileage  \
# 487             104              30           5  ...      195    86667
# 514              15              15           5  ...      358    53233
# 604              86              15           5  ...      339    19130
# 607              19               5           2  ...      302   105979
# 609              90               5           5  ...      168    32910
#
#      Comfort_Rating  Interior_Design_Rating  Performance_Rating  \
# 487             4.8                     4.8                 4.8
# 514             4.8                     4.7                 4.7
# 604             4.9                     4.8                 4.8
# 607             4.5                     4.5                 4.5
# 609             4.8                     4.8                 4.8
#
#      Value_For_Money_Rating  Exterior_Styling_Rating  Reliability_Rating  \
# 487                     4.8                      4.8                 4.9
# 514                     4.7                      4.8                 4.8
# 604                     4.8                      4.9                 4.8
# 607                     4.5                      4.6                 4.7
# 609                     4.8                      4.9                 4.9
#
#      State  Seller_Type
# 487      8            1
# 514     43            1
# 604      5            1
# 607     33            1
# 609      4            1
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Data Normalization Using MinMaxScaler

# %%
# Initialize MinMaxScaler
mms = MinMaxScaler()

# Normalisasi
standard = mms.fit_transform(used)

# Save the Normalize result to dataframe
used = pd.DataFrame(standard, columns=used.columns)

# See the data
used.head()
# Out:
#        Year  Make     Model  Condition     Price  Consumer_Rating  \
# 0  0.806452   0.0  0.097561        0.0  0.223475         0.864865
# 1  0.774194   0.0  0.016260        0.0  0.446844         0.918919
# 2  0.935484   0.0  0.032520        0.0  0.617046         0.945946
# 3  0.709677   0.0  0.203252        0.0  0.319192         0.864865
# 4  0.903226   0.0  0.105691        0.0  0.458460         0.810811
#
#    Consumer_Review_#  Exterior_Color  Interior_Color  Drivetrain  ...  \
# 0           0.006426        0.962617        0.935484         0.8  ...
# 1           0.000000        0.130841        0.451613         0.8  ...
# 2           0.000068        0.794393        0.451613         0.8  ...
# 3           0.000239        0.168224        0.129032         0.2  ...
# 4           0.119762        0.831776        0.129032         0.8  ...
#
#     Stock_#   Mileage  Comfort_Rating  Interior_Design_Rating  \
# 0  0.126056  0.333127        0.833333                0.888889
# 1  0.231969  0.203770        0.833333                0.833333
# 2  0.219623  0.071825        0.916667                0.888889
# 3  0.195582  0.407846        0.583333                0.722222
# 4  0.108512  0.125140        0.833333                0.888889
#
#    Performance_Rating  Value_For_Money_Rating  Exterior_Styling_Rating  \
# 0            0.857143                0.857143                      0.8
# 1            0.785714                0.785714                      0.8
# 2            0.857143                0.857143                      0.9
# 3            0.642857                0.642857                      0.6
# 4            0.857143                0.857143                      0.9
#
#    Reliability_Rating     State  Seller_Type
# 0                 0.9  0.142857          0.0
# 1                 0.8  0.857143          0.0
# 2                 0.8  0.081633          0.0
# 3                 0.7  0.653061          0.0
# 4                 0.9  0.061224          0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Feature selection (Choosing X and y)

# %% [markdown]
# #### Correlation

# %%
correlation = used.corr()

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlation)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature Importance

# %%
# Choosing X and y
X = used.drop(columns='Price')
y = used['Price']

# %%
# Train test split untuk feature importance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Random forest regressor untuk memilih feature importance
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# rf_fi = rf.feature_importances_
# # Menampilkan plot feature importance
# plt.figure(figsize=(6,4))
# plt.bar([x for x in range(len(rf_fi))], rf_fi)
# plt.tight_layout()
# plt.title('Feature Importance Visualization')
# plt.show()

# %%
rf_fi = rf.feature_importances_

# Define Nama columns
feature_names = X_train.columns.tolist()

plt.figure(figsize=(10, 6))

# Plotting feature importances
plt.bar(feature_names, rf_fi)
plt.xticks(rotation='vertical')
plt.xlabel('Feature Names')
plt.ylabel('Importance')
plt.title('Visualisasi Feature Importance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Memilih feature yang digunakan berdasarkan korelasi dan feature importance
used_feature = used[['Year', 'Model', 'MPG', 'VIN', 'Mileage', 'Exterior_Styling_Rating', 'Price']]
used_feature
# Out:
#           Year     Model       MPG       VIN   Mileage  \
# 0     0.806452  0.097561  0.564815  0.101365  0.333127
# 1     0.774194  0.016260  0.574074  0.116309  0.203770
# 2     0.935484  0.032520  0.694444  0.181936  0.071825
# 3     0.709677  0.203252  0.333333  0.340481  0.407846
# 4     0.903226  0.105691  0.694444  0.142300  0.125140
# ...        ...       ...       ...       ...       ...
# 1535  0.870968  0.739837  0.129630  0.728395  0.093518
# 1536  0.838710  0.138211  0.638889  0.153346  0.248210
# 1537  0.903226  0.560976  0.842593  0.404808  0.156061
# 1538  0.838710  0.439024  0.666667  0.969461  0.318576
# 1539  0.612903  0.032520  0.231481  0.096166  0.338478
#
#       Exterior_Styling_Rating     Price
# 0                         0.8  0.223475
# 1                         0.8  0.446844
# 2                         0.9  0.617046
# 3                         0.6  0.319192
# 4                         0.9  0.458460
# ...                       ...       ...
# 1535                      0.7  0.573580
# 1536                      0.8  0.383039
# 1537                      0.5  0.329766
# 1538                      0.9  0.372423
# 1539                      0.5  0.340468
#
# [1540 rows x 7 columns]

# %% [markdown]
# ### Data preparation untuk modeling Linear Regression

# %%
X = used_feature.drop(columns='Price')
y = used_feature['Price']

# %%
# Train test split, [Membagi data train dengan test (70:30)]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Scatterplot antara independen variabel dengan dependen variabel (price)

col = X.columns

#Mengatur ukuran dan layout subplot
fig, axes = plt.subplots(2, 3, figsize=(8,6))
axes = axes.flatten()

#Loop untuk membuat scatter plot
for i, prediktor in enumerate(col):
  ax = axes[i]
  ax.scatter(X[prediktor], y)
  ax.set_xlabel(prediktor)
  ax.set_ylabel('Harga mobil')
  ax.set_title(f'Scatter plot{prediktor}')

#Menampilkan plot
plt.tight_layout()
plt.show()

# %%
# Ambil 10 data pertama dari test set sebagai "data baru" untuk tahap deployment nanti
X_deploy = X_test[:10].values
y_deploy = y_test[:10].values

# %%
# Ambil data untuk test set mulai dari data ke 11 sampai terakhir
X_test = X_test[11:]
y_test = y_test[11:]

# %% [markdown]
# ---
#
# ### Modeling

# %%
# LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

print ('Coefficients: ', lr.coef_)
print ('Intercept: ', lr.intercept_)
# Out:
# Coefficients:  [ 0.56337549  0.03346843 -0.16354905  0.09109574 -0.5277513   0.07226753]
# Intercept:  0.10389793055637597

# %% [markdown]
# Penjelasan:
# - Koefisien pertama (0.56337549) menunjukkan seberapa besar pengaruh variabel independen pertama terhadap variabel dependen.
# - Koefisien kedua (0.03346843) menunjukkan pengaruh variabel independen kedua terhadap variabel dependen.
# - Koefisien ketiga (-0.16354905) menunjukkan pengaruh variabel independen ketiga terhadap variabel dependen.
# - Koefisien keempat (0.09109574) menunjukkan pengaruh variabel independen keempat terhadap variabel dependen.
# - Koefisien kelima (-0.5277513) menunjukkan pengaruh variabel independen kelima terhadap variabel dependen.
# - Koefisien keenam (0.07226753) menunjukkan pengaruh variabel independen keenam terhadap variabel dependen.
# - Intersep (0.10389793055637614) adalah nilai konstan dalam model regresi linear.

# %%
# Lihat akurasi train dan test set
print("Linear regression Train set accuracy: {}".format(np.round(lr.score(X_train, y_train), 3)))
print("Linear regression Test set accuracy: {}".format(np.round(lr.score(X_test, y_test), 3)))

# Cross-val score
print("Linear regression Train cross-validation score on training set: {}".format(np.round(cross_val_score(lr, X_train, y_train, cv=5), 3)))
print("Linear regression Train cross-validation score on testing set: {}".format(np.round(cross_val_score(lr, X_test, y_test, cv=5), 3)))
# Out:
# Linear regression Train set accuracy: 0.786
# Linear regression Test set accuracy: 0.809
# Linear regression Train cross-validation score on training set: [0.763 0.731 0.797 0.786 0.82 ]
# Linear regression Train cross-validation score on testing set: [0.838 0.852 0.807 0.738 0.734]

# %% [markdown]
# Skor cross_validation pada training set dan testing set memiliki performa yang serupa (rata-rata skor cross-validation train: 0.7794 ; rata-rata skor cross_validation test set: 0.7932), yang menunjukkan bahwa model regresi linear mungkin cukup baik dalam memodelkan hubungan antara variabel independen dan dependen.

# %%
# Buat prediksi
y_pred = lr.predict(X_test)

# %%
# Visualisasi data latih
# Mengatur ukuran dan layout subplot
col = X_train.columns

fig, axes = plt.subplots(2, 3, figsize=(8, 6))
axes = axes.flatten()

# Loop untuk membuat regplot
for i, prediktor in enumerate(col):
    ax = axes[i]
    sns.regplot(x=X_train[prediktor], y=y_train, line_kws={"color": "red"}, ax=ax)
    ax.set_xlabel(prediktor)
    ax.set_ylabel('Harga mobil')
    ax.set_title(f'Regplot {prediktor}')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
# Visualisasi harga prediksi dengan harga sebernarnya
sns.regplot(x=y_test, y=y_pred, line_kws={'color':'red'})
plt.title("Predicted Used Car Price vs Actual Car Price\n")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.tight_layout()
plt.show()

# %%
# Menyimpan model
import joblib
joblib.dump(lr, "regresi_linear.pkl")
# Out:
# ['regresi_linear.pkl']

# %% [markdown]
# ---
#
# ### Evaluation

# %%
# Initialize Mean Squared Error
mse_lr = mean_squared_error(y_test, y_pred)

# Initialize R-squared 
r2_lr = r2_score(y_test, y_pred)

print('Mean Squared Error linear regression: {:.3f}'.format(mse_lr))
print()
print('R-squared linear regression: {:.3f}%'.format(r2_lr*100))
# Out:
# Mean Squared Error linear regression: 0.007
#
# R-squared linear regression: 80.914%

# %% [markdown]
# -----
# ### Deployment

# %%
# Membuat data "baru" dengan cara memilih top 10 data dari X_test
# new data('Year', 'Model', 'MPG', 'VIN', 'Mileage', 'Transmission')
new_data = X_deploy
new_data
# Out:
# array([[0.96774194, 0.77235772, 0.12962963, 0.75178687, 0.06807164,
#         0.9       ],
#        [0.77419355, 0.71544715, 0.16666667, 0.41780377, 0.30571107,
#         0.7       ],
#        [0.87096774, 0.64227642, 0.99074074, 0.05653021, 0.34739208,
#         0.8       ],
#        [0.87096774, 0.67479675, 0.16666667, 0.46263808, 0.16851542,
#         0.7       ],
#        [0.87096774, 0.69918699, 0.16666667, 0.51786875, 0.15080302,
#         0.7       ],
#        [0.93548387, 0.08943089, 0.90740741, 0.21962313, 0.08843432,
#         0.6       ],
#        [0.90322581, 0.74796748, 0.12962963, 0.68745939, 0.16270027,
#         0.8       ],
#        [1.        , 0.21138211, 0.53703704, 0.85834958, 0.00779996,
#         0.        ],
#        [0.87096774, 0.75609756, 0.18518519, 0.66796621, 0.19212034,
#         0.7       ],
#        [0.96774194, 0.86178862, 0.2037037 , 0.57050032, 0.03158286,
#         1.        ]])

# %%
# Memuat model dari file
model = joblib.load('regresi_linear.pkl')

# %%
# Prediksi data "baru"
predict = model.predict(new_data)

# %%
print(f"Predicted: {predict}")
# Out:
# Predicted: [0.75134928 0.46405432 0.33366815 0.59370342 0.60889875 0.50221003
#  0.65115908 0.6605917  0.59964274 0.75219697]

# %%
# Menyimpan nilai minimum dan maksimum dataset asli
min_val = np.min(used_cars['Price'])
max_val = np.max(used_cars['Price'])

# Mengubah kembali nilai setelah scaling ke bentuk semula
restored_predict = (predict * (max_val - min_val)) + min_val
restored_actual = (y_deploy * (max_val - min_val)) + min_val

# %%
import pandas as pd

# Helper function to format value as Rupiah
def format_as_rupiah(value):
    value_str = "{:,.2f}".format(value)  # Format as decimal with two decimal places
    return "US $ " + value_str.replace(",", ".")  # Add "Rp" and replace comma with dot

# Membuat DataFrame dari ketiga kolom
df = pd.DataFrame({'Dataset asli': restored_actual, 'Predict Deployment': restored_predict})

# Mengubah format nilai dalam DataFrame menjadi Rupiah
df = df.applymap(lambda x: format_as_rupiah(x) if isinstance(x, (int, float)) else x)

# Menampilkan tabel
df
# Out:
#      Dataset asli Predict Deployment
# 0  US $ 42.995.00     US $ 37.310.67
# 1  US $ 17.690.00     US $ 23.806.95
# 2  US $ 18.753.00     US $ 17.678.40
# 3  US $ 32.999.00     US $ 29.900.84
# 4  US $ 35.873.00     US $ 30.615.07
# 5  US $ 33.488.00     US $ 25.600.38
# 6  US $ 31.997.00     US $ 32.601.43
# 7  US $ 35.562.00     US $ 33.044.79
# 8  US $ 27.845.00     US $ 30.180.01
# 9  US $ 42.988.00     US $ 37.350.51
